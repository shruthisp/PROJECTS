# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Analysis of SAT & ACT datasets for 2019 and a peek into the test-optional admissions criteria

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# High school students often know which colleges they would like to consider, but rarely know what SAT or ACT score they should aim for when applying to these colleges. This project aims to explore the relation between
#  - the SAT score and the College Majors
#  - trends in SAT and ACT participation for the year 2019
#
# What we would also like to see here is: Is there a relation between the number of applicants and the acceptance rates. How does the college prestige and acceptance rates relate. Will the test-option decision help the admission boards to evaluate the students based on GPA and overall achievements and not just a single test?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# Increasing number of universities are dropping SAT and ACT requirement for fall of 2021 admissions in response to the coronavirus pandemic.([source](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html))Some of them announced it's going test-optional. This decision could benefit a lot of people: those students who no longer have access to test prep and other resources, schools can get more applicants and a more diverse pool of applicants, students will have the opportunity to be evaluated by more than just a score.
#
# "Pre-pandemic there were 1,070 schools that were test-optional – one of whom was test-blind. Now there are 1,686, including 68 that are test-blind for fall 2021," Schaeffer says.([*source*](https://www.usnews.com/education/best-colleges/articles/how-the-coronavirus-is-pushing-colleges-to-go-test-optional)) What Test-Optional Means for Students: test-optional means students are not required to submit standardized test scores on their college admissions application, whether to do so is up to the student. Test-blind means that colleges won't look at scores even if a student submits them.
#
# In this project we will look for trends or relations between the acceptance rates for SAT and ACT scores of 2019, their average scores accross the states. SAT and ACT scores for intended majors. We would also like to see how the acceptence rates fare for the prestigious schools. There are many criterias that makes an educationa institution prestigeious, the Reputation, Selectivity Funding, Faculty and more. For the sake of this project, we will be looking closely at the acceptance rates as the Selectivity criteria for the students, lower acceptance rates should correspond to prestigious schools/colleges.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# Before the pandemic, a growing number of colleges stopped requiring applicants to submit SAT or ACT scores, as a way to increase diversity on their campuses. But researchers are finding that the test-optional policy isn’t substantially raising the share of low-income students or students of color at colleges that have tried it.
# The latest study, published in the peer-reviewed American Educational Research Journal in April 2021, found that test-optional admissions increased the share of Black, Latino and Native American students by only 1 percentage point at about 100 colleges and universities that adopted the policy between 2005-06 and 2015-16. The share of low-income students, as measured by those who qualify for federal Pell Grants, also increased by only 1 percentage point on these campuses, compared to similar schools that continued to require SAT and ACT scores.
# It will be interesting to see how the diversity of the 2021-22 freshman classes change when all the data are in. The other way to look at this is, if these colleges are picky, it could slow the momentum of test-optional admissions. Colleges had to hire many more admissions staffers and application readers to sift through applications without test scores. Test scores are an efficient way to reduce the applicant pool. Having said this, will the colleges go test-optional or test-free in the near future? Only time and data will tell!
#
# ([source](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/))
# ([source](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html))
# ([source](https://oedb.org/rankings/acceptance-rate/))
# ([source](https://education.seattlepi.com/university-prestigious-1307.html))
# ([source](https://hechingerreport.org/proof-points-test-optional-policies-didnt-do-much-to-diversify-college-student-populations/))
# ([source](https://medium.com/@james.dargan/participation-skews-state-averages-f68969371a01))
# ([source](https://www.smithsonianmag.com/innovation/has-pandemic-put-end-to-sat-act-180978167/))

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def mean_value(values):
    sum_values=0
    for i in values:
        sum_values+=i
    return sum_values/len(values)

mean_value([1,4,12,34,45,23,13,14,15,34,35,37,26,27,22,33,39])
# Out:
# 24.352941176470587

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_dev(values):
    m = mean_value(values)
    n = len(values)
    result = 0
    for i in values:
        result += (i-m)**2    
    return (result/n)**0.5

std_dev([2,3,4,5,6,7])
# Out:
# 1.707825127659933

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:

def percent_conv(num):

    string = '1234567890.'
    num_p = ''
    if type(num)== float:
        return num
    else:
        for i in num:
            if i in string:
                num_p= num_p + i
                num = float(num_p)/100
    return num            
    
    
    
percent_conv('30.6%')
# Out:
# 0.306

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:
# Data Importing
sat_19 = pd.read_csv('../data/sat_2019.csv')
act_19 = pd.read_csv('../data/act_2019.csv')
sat_act_bycollege = pd.read_csv('../data/sat_act_by_college.csv')
sat_collegemajor = pd.read_csv('../data/sat_2019_by_intended_college_major.csv')

# %%
#First 5 rows SAT 2019 dataset that we have used in this analysis

sat_19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
#First 5 rows ACT 2019 dataset that we have used in this analysis

act_19.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
#adjust the total to be equal to EBRW + Math scores because some scores were not adding up to the total.
sat_19['new_total']  = sat_19['EBRW']+sat_19['Math']
sat_19['total_diff'] = sat_19['new_total']-sat_19['Total']
sat_19.head()
# we can see that there are descrepencies with the Totals column. 
# Hence we can keep the new total and drop the old Total column and the total_diff column
# Out:
#         State Participation Rate  EBRW  Math  Total  new_total  total_diff
# 0     Alabama                 7%   583   560   1143       1143           0
# 1      Alaska                41%   556   541   1097       1097           0
# 2     Arizona                31%   569   565   1134       1134           0
# 3    Arkansas                 6%   582   559   1141       1141           0
# 4  California                63%   534   531   1065       1065           0

# %%
sat_19.drop(columns = ['Total', 'total_diff'], inplace=True)
# Out:
#         State Participation Rate  EBRW  Math  new_total
# 0     Alabama                 7%   583   560       1143
# 1      Alaska                41%   556   541       1097
# 2     Arizona                31%   569   565       1134
# 3    Arkansas                 6%   582   559       1141
# 4  California                63%   534   531       1065

# %%
#SAT 2019 dataset after dropping the columns
sat_19.head()
# Out:
#         State Participation Rate  EBRW  Math  new_total
# 0     Alabama                 7%   583   560       1143
# 1      Alaska                41%   556   541       1097
# 2     Arizona                31%   569   565       1134
# 3    Arkansas                 6%   582   559       1141
# 4  California                63%   534   531       1065

# %% [markdown]
# The SAT and ACT scores data sets are listed according to the states in the United States of America. SAT scores are based on Math and Evidence-based Reading and Writing while ACT scores are based on English, Math, Reading and Science.

# %%
#First 5 rows SAT and ACT by college dataset that we have used in this analysis

sat_act_bycollege.head()
# Out:
#                  School Test Optional? Applies to Class Year(s)  \
# 0   Stanford University            Yes                     2021
# 1       Harvard College            Yes                     2021
# 2  Princeton University            Yes                     2021
# 3   Columbia University            Yes                     2021
# 4       Yale University            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile
# ...

# %%
#First 5 rows SAT and ACT by college dataset that we have used in this analysis

sat_collegemajor.head()
# Out:
#                                 IntendedCollegeMajor TestTakers Percent  \
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                  Architecture and Related Services     28,988      2%
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 3                 Biological and Biomedical Sciences    155,834      8%
# 4  Business, Management, Marketing, and Related S...    221,523     12%
#
#    Total  ReadingWriting  Math
# 0    977             496   481
# 1   1047             520   527
# 2   1040             536   504
# 3   1139             572   566
# 4   1072             534   537

# %%
# function to show the summary data of all the dataset used for this analysis
def summary(df):  
    return print('-----Info/DataTypes-----'), df.info(), \
            print('-----Missing Values/Describe-----'), df.isnull().sum(),df.describe()

# %%
summary(sat_19)
# Out:
# -----Info/DataTypes-----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   new_total           53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB
# -----Missing Values/Describe-----
# (None,
#  None,
#  None,
#  State                 0
#  Participation Rate    0
#  EBRW                  0
#  Math                  0
#  new_total             0
#  dtype: int64,
#               EBRW        Math    new_total
#  count   53.000000   53.000000    53.000000
#  mean   558.000000  548.471698  1106.471698
#  std     47.554422   53.785044   100.959170
#  min    483.000000  445.000000   935.000000
# ...

# %%
summary(act_19)
# Out:
# -----Info/DataTypes-----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB
# -----Missing Values/Describe-----
# (None,
#  None,
#  None,
#  State            0
#  Participation    0
#  Composite        0
#  dtype: int64,
#         Composite
#  count  52.000000
#  mean   21.450000
#  std     2.175487
#  min    17.900000
#  25%    19.800000
#  50%    20.950000
#  75%    23.650000
#  max    25.500000)

# %%
summary(sat_act_bycollege)
# Out:
# -----Info/DataTypes-----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   School                          416 non-null    object
#  1   Test Optional?                  416 non-null    object
#  2   Applies to Class Year(s)        390 non-null    object
#  3   Policy Details                  416 non-null    object
#  4   Number of Applicants            416 non-null    int64
#  5   Accept Rate                     416 non-null    object
#  6   SAT Total 25th-75th Percentile  416 non-null    object
#  7   ACT Total 25th-75th Percentile  416 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 26.1+ KB
# -----Missing Values/Describe-----
# (None,
#  None,
#  None,
#  School                             0
#  Test Optional?                     0
#  Applies to Class Year(s)          26
# ...

# %%
summary(sat_collegemajor)
# Out:
# -----Info/DataTypes-----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IntendedCollegeMajor  38 non-null     object
#  1   TestTakers            38 non-null     object
#  2   Percent               38 non-null     object
#  3   Total                 38 non-null     int64
#  4   ReadingWriting        38 non-null     int64
#  5   Math                  38 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1.9+ KB
# -----Missing Values/Describe-----
# (None,
#  None,
#  None,
#  IntendedCollegeMajor    0
#  TestTakers              0
#  Percent                 0
#  Total                   0
#  ReadingWriting          0
#  Math                    0
#  dtype: int64,
#               Total  ReadingWriting        Math
#  count    38.000000       38.000000   38.000000
# ...

# %% [markdown]
# ### Data Cleaning

# %%
# Converting some of the missing values in the SAT 2019 dataset to NaN

sat_19['Participation Rate']= sat_19['Participation Rate'].map(lambda x: np.nan if x == '—' else x)

# %%
# Droping the NaN values, the States fo Puerto Rico and Virgin Islands had missing Participation rates.
# For the sake of this analysis our datasets do not include the above mentioned States.

sat_19.dropna(subset =['Participation Rate'], inplace=True)

# %%
#Convert all the values in percentages to decimals

sat_19['participation_rate'] = sat_19['participation_rate'].apply(lambda x: percent_conv(x))
act_19['participation'] = act_19['participation'].apply(lambda x: percent_conv(x))

# %%
# Change capitalized letters to lower case 
sat_19.columns = sat_19.columns.str.lower()
act_19.columns = act_19.columns.str.lower()
sat_act_bycollege.columns = sat_act_bycollege.columns.str.lower()
sat_collegemajor.columns = sat_collegemajor.columns.str.lower()

# %%
# Change spaces to underscore
sat_19.columns = sat_19.columns.str.replace(' ', '_')
act_19.columns = act_19.columns.str.replace(' ', '_')
sat_act_bycollege.columns = sat_act_bycollege.columns.str.replace(' ', '_')

# %%
sat_19['participation_rate']=sat_19['participation_rate'].replace('—', np.NaN)

# %%
# Rename columns in act_19 datset
act_19.rename(columns={act_19.columns[0]:'state'}, inplace=True)
act_19.rename(columns={act_19.columns[1]:'act_participation'}, inplace=True)
act_19.rename(columns={act_19.columns[2]:'act_composite'}, inplace=True)

act_19.head()
# Out:
#         state  act_participation  act_composite
# 0     Alabama               1.00           18.9
# 1      Alaska               0.38           20.1
# 2     Arizona               0.73           19.0
# 3    Arkansas               1.00           19.3
# 4  California               0.23           22.6

# %%
# Rename columns in sat_19 datset

sat_19.rename(columns={sat_19.columns[0]:'state'}, inplace=True)
sat_19.rename(columns={sat_19.columns[1]:'sat_participation'}, inplace=True)
sat_19.rename(columns={sat_19.columns[2]:'sat_reading_and_writing'}, inplace=True)
sat_19.rename(columns={sat_19.columns[3]:'sat_math'}, inplace=True)
sat_19.rename(columns={sat_19.columns[4]:'sat_total'}, inplace=True)

sat_19.head()
# Out:
#         state  sat_participation  sat_reading_and_writing  sat_math  sat_total
# 0     Alabama               0.07                      583       560       1143
# 1      Alaska               0.41                      556       541       1097
# 2     Arizona               0.31                      569       565       1134
# 3    Arkansas               0.06                      582       559       1141
# 4  California               0.63                      534       531       1065

# %%
# Data cleaning for the sat_act_bycollege dataset
# Convert the Accept_rate column percentage string to decimal

sat_act_bycollege['accept_rate'] = sat_act_bycollege['accept_rate'].apply(lambda x: percent_conv(x))
sat_act_bycollege.head()
# Out:
#                  school test_optional? applies_to_class_year(s)  \
# 0   Stanford University            Yes                     2021
# 1       Harvard College            Yes                     2021
# 2  Princeton University            Yes                     2021
# 3   Columbia University            Yes                     2021
# 4       Yale University            Yes                     2021
#
#                                       policy_details  number_of_applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#    accept_rate sat_total_25th-75th_percentile act_total_25th-75th_percentile
# ...

# %%
sat_act_bycollege['test_optional?'].value_counts()
# Out:
# Yes         347
# No           26
# Yes (TB)     25
# Yes*         16
# Yes (TF)      2
# Name: test_optional?, dtype: int64

# %%
# Splitting the test_optional column based on whether or not the test is optional, yes(TB),(TF),*, No 


sat_act_bycollege = pd.get_dummies(sat_act_bycollege, columns=['test_optional?'])
sat_act_bycollege.head()
# Out:
#                  school applies_to_class_year(s)  \
# 0   Stanford University                     2021
# 1       Harvard College                     2021
# 2  Princeton University                     2021
# 3   Columbia University                     2021
# 4       Yale University                     2021
#
#                                       policy_details  number_of_applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#    accept_rate sat_total_25th-75th_percentile act_total_25th-75th_percentile  \
# 0        0.043                      1440-1570                          32-35
# ...

# %%
#convert the applies_to_class_year column to number of years starting from 2021 
#For example, 
# 2021 ---> 1 
# 2021, 2022 ---> 2
# 2021..... 2025 ---> 5
# All / Permanent Policy ---> 100. (a reasonably large number)

# splitting the applies_to_class_year column
sat_act_bycollege = pd.get_dummies(sat_act_bycollege, columns=['applies_to_class_year(s)'])
sat_act_bycollege.head()
# Out:
#                  school                                     policy_details  \
# 0   Stanford University  Stanford has adopted a one-year test optional ...
# 1       Harvard College  Harvard has adopted a one-year test optional p...
# 2  Princeton University  Princeton has adopted a one-year test optional...
# 3   Columbia University  Columbia has adopted a one-year test optional ...
# 4       Yale University  Yale has adopted a one-year test optional poli...
#
#    number_of_applicants  accept_rate sat_total_25th-75th_percentile  \
# 0                 47452        0.043                      1440-1570
# 1                 42749        0.047                      1460-1580
# 2                 35370        0.055                      1440-1570
# 3                 40203        0.055                      1450-1560
# 4                 36844        0.061                      1460-1570
#
#   act_total_25th-75th_percentile  test_optional?_No  test_optional?_Yes  \
# ...

# %%
# Merging the columns created above into one column 

sat_act_bycollege['years_applicable_from_2021'] = sat_act_bycollege['applies_to_class_year(s)_2021'] + \
                                                  sat_act_bycollege['applies_to_class_year(s)_2021 2022']*2 + \
                                                sat_act_bycollege['applies_to_class_year(s)_2021 2022 2023']*3 + \
                                                sat_act_bycollege['applies_to_class_year(s)_2021 2022 2023 2024']*4 +\
                                                sat_act_bycollege['applies_to_class_year(s)_2021 2022 2023 2024 2025']*5 +\
                                                sat_act_bycollege['applies_to_class_year(s)_All / Permanent Policy']*100 



sat_act_bycollege.head()
# Out:
#                  school                                     policy_details  \
# 0   Stanford University  Stanford has adopted a one-year test optional ...
# 1       Harvard College  Harvard has adopted a one-year test optional p...
# 2  Princeton University  Princeton has adopted a one-year test optional...
# 3   Columbia University  Columbia has adopted a one-year test optional ...
# 4       Yale University  Yale has adopted a one-year test optional poli...
#
#    number_of_applicants  accept_rate sat_total_25th-75th_percentile  \
# 0                 47452        0.043                      1440-1570
# 1                 42749        0.047                      1460-1580
# 2                 35370        0.055                      1440-1570
# 3                 40203        0.055                      1450-1560
# 4                 36844        0.061                      1460-1570
#
#   act_total_25th-75th_percentile  test_optional?_No  test_optional?_Yes  \
# ...

# %%
# Drop the unwanted columns
sat_act_bycollege.drop(columns = ['applies_to_class_year(s)_2021', 'applies_to_class_year(s)_2021 2022', \
                                 'applies_to_class_year(s)_2021 2022 2023', 'applies_to_class_year(s)_2021 2022 2023 2024', \
                                 'applies_to_class_year(s)_2021 2022 2023 2024 2025', \
                                  'applies_to_class_year(s)_All / Permanent Policy'], inplace=True)
sat_act_bycollege.head()
# Out:
#                  school                                     policy_details  \
# 0   Stanford University  Stanford has adopted a one-year test optional ...
# 1       Harvard College  Harvard has adopted a one-year test optional p...
# 2  Princeton University  Princeton has adopted a one-year test optional...
# 3   Columbia University  Columbia has adopted a one-year test optional ...
# 4       Yale University  Yale has adopted a one-year test optional poli...
#
#    number_of_applicants  accept_rate sat_total_25th-75th_percentile  \
# 0                 47452        0.043                      1440-1570
# 1                 42749        0.047                      1460-1580
# 2                 35370        0.055                      1440-1570
# 3                 40203        0.055                      1450-1560
# 4                 36844        0.061                      1460-1570
#
#   act_total_25th-75th_percentile  test_optional?_No  test_optional?_Yes  \
# ...

# %%
sat_act_bycollege['years_applicable_from_2021'].value_counts()
# Out:
# 1      196
# 100    158
# 0       26
# 3       15
# 2       11
# 4        9
# 5        1
# Name: years_applicable_from_2021, dtype: int64

# %%
# Converting the sat_total_25th-75th_percentile and act_total_25th-75th_percentile into sat_25th_percentile, 
# sat_75th_percentile, act_25th_percentile, act_75th_percentile

new = sat_act_bycollege['sat_total_25th-75th_percentile'].str.split('-', expand = True)
sat_act_bycollege['sat_25th_percentile']=new[0]
sat_act_bycollege['sat_75th_percentile']=new[1]
sat_act_bycollege.drop(columns=['sat_total_25th-75th_percentile'], inplace = True)

new_act = sat_act_bycollege['act_total_25th-75th_percentile'].str.split('-', expand = True)
sat_act_bycollege['act_25th_percentile']=new_act[0]
sat_act_bycollege['act_75th_percentile']=new_act[1]
sat_act_bycollege.drop(columns=['act_total_25th-75th_percentile'], inplace = True)

sat_act_bycollege.head(2)
# Out:
#                 school                                     policy_details  \
# 0  Stanford University  Stanford has adopted a one-year test optional ...
# 1      Harvard College  Harvard has adopted a one-year test optional p...
#
#    number_of_applicants  accept_rate  test_optional?_No  test_optional?_Yes  \
# 0                 47452        0.043                  0                   1
# 1                 42749        0.047                  0                   1
#
#    test_optional?_Yes (TB)  test_optional?_Yes (TF)  test_optional?_Yes*  \
# 0                        0                        0                    0
# 1                        0                        0                    0
#
#    years_applicable_from_2021 sat_25th_percentile sat_75th_percentile  \
# 0                           1                1440                1570
# 1                           1                1460                1580
#
#   act_25th_percentile act_75th_percentile
# ...

# %%
# Convert the data type for the columns to float
sat_act_bycollege['sat_25th_percentile']= pd.to_numeric(sat_act_bycollege['sat_25th_percentile'], errors='coerce')
sat_act_bycollege['sat_75th_percentile']= pd.to_numeric(sat_act_bycollege['sat_75th_percentile'], errors='coerce')
sat_act_bycollege['act_25th_percentile']= pd.to_numeric(sat_act_bycollege['act_25th_percentile'], errors='coerce')
sat_act_bycollege['act_75th_percentile']= pd.to_numeric(sat_act_bycollege['act_75th_percentile'], errors='coerce')
sat_act_bycollege.dtypes
# Out:
# school                         object
# policy_details                 object
# number_of_applicants            int64
# accept_rate                   float64
# test_optional?_No               uint8
# test_optional?_Yes              uint8
# test_optional?_Yes (TB)         uint8
# test_optional?_Yes (TF)         uint8
# test_optional?_Yes*             uint8
# years_applicable_from_2021      uint8
# sat_25th_percentile           float64
# sat_75th_percentile           float64
# act_25th_percentile           float64
# act_75th_percentile           float64
# dtype: object

# %%
#Data cleaning for the sat_collegemajor dataset
# convert the TestTakers column from str to int
sat_collegemajor['TestTakers'] = sat_collegemajor['TestTakers'].str.replace(',','')
sat_collegemajor['TestTakers'] = sat_collegemajor['TestTakers'].astype(int)

# %%
# Convert the percent column from string to float 
sat_collegemajor['Percent'] = sat_collegemajor['Percent'].apply(lambda x: percent_conv(x))
sat_collegemajor.head()
# Out:
#                                 intendedcollegemajor  testtakers  percent  \
# 0  Agriculture, AgricultureOperations, and Relate...       24913     0.01
# 1                  Architecture and Related Services       28988     0.02
# 2         Area, Ethnic, Cultural, and Gender Studies        2629     0.00
# 3                 Biological and Biomedical Sciences      155834     0.08
# 4  Business, Management, Marketing, and Related S...      221523     0.12
#
#    total  readingwriting  math
# 0    977             496   481
# 1   1047             520   527
# 2   1040             536   504
# 3   1139             572   566
# 4   1072             534   537

# %%
# Rename columns:
sat_collegemajor.rename(columns={sat_collegemajor.columns[0]:'college_major'}, inplace=True)
sat_collegemajor.rename(columns={sat_collegemajor.columns[1]:'sat_testtakers'}, inplace=True)
sat_collegemajor.rename(columns={sat_collegemajor.columns[2]:'accept_rate'}, inplace=True)
sat_collegemajor.rename(columns={sat_collegemajor.columns[3]:'sat_total'}, inplace=True)
sat_collegemajor.rename(columns={sat_collegemajor.columns[4]:'sat_reading_writing'}, inplace=True)
sat_collegemajor.rename(columns={sat_collegemajor.columns[5]:'sat_math'}, inplace=True)
sat_collegemajor.head()
# Out:
#                                        college_major  sat_testtakers  \
# 0  Agriculture, AgricultureOperations, and Relate...           24913
# 1                  Architecture and Related Services           28988
# 2         Area, Ethnic, Cultural, and Gender Studies            2629
# 3                 Biological and Biomedical Sciences          155834
# 4  Business, Management, Marketing, and Related S...          221523
#
#    accept_rate  sat_total  sat_reading_writing  sat_math
# 0         0.01        977                  496       481
# 1         0.02       1047                  520       527
# 2         0.00       1040                  536       504
# 3         0.08       1139                  572       566
# 4         0.12       1072                  534       537

# %%
# Creating a new total column for the dataset since the old total column had some discrepencies.
sat_collegemajor['new_sat_total']=sat_collegemajor['sat_reading_writing']+sat_collegemajor['sat_math']
sat_collegemajor.drop(columns = ['sat_total'], inplace=True)
sat_collegemajor
# Out:
#                                         college_major  sat_testtakers  \
# 0   Agriculture, AgricultureOperations, and Relate...           24913
# 1                   Architecture and Related Services           28988
# 2          Area, Ethnic, Cultural, and Gender Studies            2629
# 3                  Biological and Biomedical Sciences          155834
# 4   Business, Management, Marketing, and Related S...          221523
# 5     Communication, Journalism, and Related Programs           36332
# 6   Computer and Information Sciences and Support ...           79736
# 7                        Construction Trades, General            2500
# 8                                           Education           71882
# 9                                         Engineering          194127
# 10               Engineering Technologies/Technicians           33595
# 11            English Language and Literature/Letters           16233
# ...

# %% [markdown]
# #### Merging the SAT and ACT data sets  into a single dataset

# %%
#Drop unnecessary columns 
#ACT 2019 data has a National state, which has to be dropped, 
# while SAT 2019 has Puerto Rico and Virgin Islands with NaN values

sat_19.dropna(subset= ['sat_participation'], inplace=True)
act_19.drop(51, axis=0, inplace = True)

# %%
#merging the SAT 2019 and ACT 2019 dataframes
sat_act_19 = pd.merge(sat_19, act_19, on='state')

sat_act_19.dtypes
# Out:
# state                       object
# sat_participation          float64
# sat_reading_and_writing      int64
# sat_math                     int64
# sat_total                    int64
# act_participation          float64
# act_composite              float64
# dtype: object

# %%
# saving the new dataframes as csv files
sat_act_19.to_csv(r'./sat_act_19.csv')
sat_collegemajor.to_csv(r'./sat_collegemajor.csv')
sat_act_bycollege.to_csv(r'./sat_act_bycollege.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# ### Data Dictionary
#
# |Feature|Type|Dataset|Description|
# |:---|:---:|:---:|:---|
# |**state**|*object*|2019 Average SAT and ACT Scores by State |State in the United states of America.|
# |**sat_participation**|*float64*|2019 Average SAT Scores by State|The percentage expressed as a float on the number of students enrolled in schools.|
# |**sat_reading_and_writing**|*int64*|2019 Average SAT Scores by State |The average English reading and writing score in a maximum score of 800.|
# |**sat_math**|*int64*|2019 Average SAT Scores by State |The average math score in a maximum score of 800.|
# |**sat_total**|*int64*|2019 Average SAT Scores by State |The combined score of sat_reading_and_writing and sat_math.|
# |**act_participation**|*float64*|2019 Average ACT Scores by State|The percentage expressed as a float on the number of students enrolled in schools.|
# |**act_composite**|*float64*|2019 Average ACT Scores by State |The average of the 4 ACT scores for the state.|
# |**college_major**|*object*|SAT Participation and Performance:Intended College Major|Intended College Major.|
# |**sat_testtakers**|*int64*|SAT Participation and Performance:Intended College Major|2019 highschool graduates who took SAT during highschool.|
# |**accept_rate**|*float64*|SAT Participation and Performance:Intended College Major |The percentage expressed as a float on the number of students that were accepted.|
# |**sat_reading_writing**|*int64*|SAT Participation and Performance:Intended College Major|Mean score of SAT English reading and writing.|
# |**sat_math**|*int64*|SAT Participation and Performance:Intended College Major|Mean score of SAT math test.|
# |**new_sat_total**|*int64*|SAT Participation and Performance:Intended College Major|The combined score of sat_reading_and_writing and sat_math.|
# |**school**|*object*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |The names of popular four-year postsecondary institutions in the U.S.|
# |**policy_details**|*object*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |Admission testing policies for the colleges and universities.|
# |**number_of_applicants**|*int64*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |Number of applicants for the colleges and universities.|
# |**accept_rate**|*float64*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |The percentage accepted expressed as a float.|
# |**sat_25th & 75th_percentile**|*float64*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |Range of SAT scores of enrolled students.|
# |**act_25th & 75th_percentile**|*float64*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |Range of ACT scores of enrolled students.|
# |**test_optional?_No**|*uint8*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |Test policy of the school- SAt/ACT is NOT optional.|
# |**test_optional?_Yes**|*uint8*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |Test policy of the school- SAt/ACT is optional.|
# |**test_optional?_Yes (TB)**|*uint8*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |Test policy of the school- SAt/ACT is optional and test blind-meaning the policy will be re-evaluated at the end of the applicable period.|
# |**test_optional?_Yes (TF)**|*uint8*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |Test policy of the school- SAt/ACT is not required or Test Free.|
# |**test_optional?_Yes***|*uint8*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |Test policy of the school- SAt/ACT is Test Optional for some students and the admittance will be evaluated based on a GPA cut off.|
# |**years_applicable_from_2021**|*uint8*|SAT and ACT Policies and Score Ranges for Popular Colleges and Universities |Number of years the test policy of the school is applicable.|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Read/import the cleaned the datasets 
my_sat_act_19 = pd.read_csv('./sat_act_19.csv')
my_sat_collegemajor = pd.read_csv('./sat_collegemajor.csv')
my_sat_act_bycollege = pd.read_csv('./sat_act_bycollege.csv')

# %%
my_sat_act_19.drop(columns = 'Unnamed: 0', inplace = True)

my_sat_act_19.describe().T
# Out:
#                          count         mean        std     min       25%  \
# sat_participation         51.0     0.490588   0.387476    0.02     0.055
# sat_reading_and_writing   51.0   560.803922  46.248035  483.00   527.500
# sat_math                  51.0   552.196078  51.290553  460.00   511.500
# sat_total                 51.0  1113.078431  97.197910  943.00  1038.000
# act_participation         51.0     0.586667   0.345159    0.06     0.245
# act_composite             51.0    21.464706   2.194523   17.90    19.800
#
#                              50%      75%     max
# sat_participation           0.54     0.82     1.0
# sat_reading_and_writing   550.00   612.00   636.0
# sat_math                  546.00   599.00   648.0
# sat_total                1097.00  1210.00  1284.0
# act_participation           0.54     1.00     1.0
# act_composite              21.10    23.70    25.5

# %% [markdown]
# ### Interpretation:
# The .describe() commands above provide basic descriptive statistics for each column in the two dataframes, including mean, standard deviation, minimum and maximum values, as well as Q1, median, and Q3 percentile values.

# %%
my_sat_collegemajor.drop(columns = 'Unnamed: 0', inplace = True)

my_sat_collegemajor.describe().T
# Out:
#                      count          mean           std    min      25%  \
# sat_testtakers        38.0  48394.500000  72753.092558  283.0  6611.00
# accept_rate           38.0      0.025789      0.039975    0.0     0.00
# sat_reading_writing   38.0    535.500000     41.362439  458.0   501.25
# sat_math              38.0    523.000000     43.386385  456.0   486.50
# new_sat_total         38.0   1058.500000     82.445641  916.0   988.25
#
#                           50%        75%        max
# sat_testtakers       16370.50  60215.750  331026.00
# accept_rate              0.01      0.035       0.18
# sat_reading_writing    537.00    569.750     597.00
# sat_math               527.00    542.250     646.00
# new_sat_total         1066.50   1114.750    1243.00

# %%
my_sat_act_bycollege.drop(columns = 'Unnamed: 0', inplace = True)

my_sat_act_bycollege.describe().T
# Out:
#                             count          mean           std       min  \
# number_of_applicants        416.0  17481.759615  17447.621897   211.000
# accept_rate                 416.0      0.557034      0.242117     0.043
# test_optional?_No           416.0      0.062500      0.242353     0.000
# test_optional?_Yes          416.0      0.834135      0.372408     0.000
# test_optional?_Yes (TB)     416.0      0.060096      0.237951     0.000
# test_optional?_Yes (TF)     416.0      0.004808      0.069254     0.000
# test_optional?_Yes*         416.0      0.038462      0.192539     0.000
# years_applicable_from_2021  416.0     38.711538     48.024426     0.000
# sat_25th_percentile         406.0   1163.826355    126.125090   793.000
# sat_75th_percentile         410.0   1358.892683    111.431443  1050.000
# act_25th_percentile         410.0     24.712927      4.127758    15.000
# act_75th_percentile         410.0     29.889756      3.154675    19.000
#
# ...

# %%
# Standard devation using dictionary comprehension for sat_act_19 dataset
sd1={col.name:std_dev(col) for col in [my_sat_act_19[i] for i in my_sat_act_19.columns if \
                                       (my_sat_act_19[i].dtype=='float64') or (my_sat_act_19[i].dtype=='int64')]}

sd1
# Out:
# {'sat_participation': 0.3836584048685726,
#  'sat_reading_and_writing': 45.792378682545134,
#  'sat_math': 50.78521461840036,
#  'sat_total': 96.24027185617864,
#  'act_participation': 0.3417582373703047,
#  'act_composite': 2.172901153595978}

# %%
# Standard devation using dictionary comprehension for sat_collegemajor dataset

sd2={col.name:std_dev(col) for col in [my_sat_collegemajor[i] for i in my_sat_collegemajor.columns if \
                                       (my_sat_collegemajor[i].dtype=='float64') or \
                                       (my_sat_collegemajor[i].dtype=='int64')]}

sd2
# Out:
# {'sat_testtakers': 71789.43289002257,
#  'accept_rate': 0.03944560404747735,
#  'sat_reading_writing': 40.814567832679806,
#  'sat_math': 42.811705236572365,
#  'new_sat_total': 81.35359792127723}

# %%
# Standard devation using dictionary comprehension for sat_collegemajor dataset

sd3={col.name:std_dev(col) for col in [my_sat_act_bycollege[i] for i in my_sat_act_bycollege.columns if \
                                       (my_sat_act_bycollege[i].dtype=='float64') or \
                                       (my_sat_act_bycollege[i].dtype=='int64') or \
                                       (my_sat_act_bycollege[i].dtype=='uint8')]}

sd3
# Out:
# {'number_of_applicants': 17426.638579835628,
#  'accept_rate': 0.24182623255559774,
#  'test_optional?_No': 0.24206145913796356,
#  'test_optional?_Yes': 0.37195975427695754,
#  'test_optional?_Yes (TB)': 0.2376649030442942,
#  'test_optional?_Yes (TF)': 0.06917064697085669,
#  'test_optional?_Yes*': 0.19230769230769246,
#  'years_applicable_from_2021': 47.96666973352892,
#  'sat_25th_percentile': nan,
#  'sat_75th_percentile': nan,
#  'act_25th_percentile': nan,
#  'act_75th_percentile': nan}

# %%
# Investigate trends in the data
# States that have highest participation rates for SAT in 2019, above the rate of 90%

participation = my_sat_act_19[['state','sat_participation','act_participation']]

max_sat = participation[participation['sat_participation']>0.90].sort_values(by=['sat_participation'], ascending=False)
max_sat.head(8)
# Out:
#            state  sat_participation  act_participation
# 5       Colorado                1.0               0.27
# 6    Connecticut                1.0               0.22
# 7       Delaware                1.0               0.13
# 9        Florida                1.0               0.54
# 12         Idaho                1.0               0.31
# 13      Illinois                1.0               0.35
# 22      Michigan                1.0               0.19
# 39  Rhode Island                1.0               0.12

# %% [markdown]
# #### Interpretation:
# The states with 100% SAT test participation rates for the year 2019 are Colorado, Connecticut, Delaware, Florida, Idaho, Illinois, Michigan and Rhode Island.It can also be interpreted that the states that have highest participation in SATs have lower participation rates in ACTs

# %%
# States that have highest participation rates for ACT in 2019, above the rate of 90%

max_act = participation[participation['act_participation']>0.90].sort_values(by=['act_participation'], ascending=False)
max_act.head(15)
# Out:
#              state  sat_participation  act_participation
# 0          Alabama               0.07                1.0
# 3         Arkansas               0.06                1.0
# 49       Wisconsin               0.03                1.0
# 44            Utah               0.04                1.0
# 42       Tennessee               0.07                1.0
# 36        Oklahoma               0.22                1.0
# 35            Ohio               0.19                1.0
# 33  North Carolina               0.51                1.0
# 28          Nevada               0.20                1.0
# 27        Nebraska               0.03                1.0
# 26         Montana               0.09                1.0
# 24     Mississippi               0.03                1.0
# 18       Louisiana               0.05                1.0
# 17        Kentucky               0.04                1.0
# 50         Wyoming               0.03                1.0

# %%
participation['total'] = participation['sat_participation']+participation['act_participation'] 

sorted_act= participation.sort_values(by =['total', 'sat_participation'], ascending = False)

sorted_act.tail()
# Out:
# <ipython-input-248-f43093793af7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   participation['total'] = participation['sat_participation']+participation['act_participation']
#            state  sat_participation  act_participation  total
# 31    New Mexico               0.18               0.63   0.81
# 1         Alaska               0.41               0.38   0.79
# 41  South Dakota               0.03               0.75   0.78
# 16        Kansas               0.04               0.72   0.76
# 15          Iowa               0.03               0.66   0.69

# %% [markdown]
# #### Interpretation:
# The states with 100% participation in ACT tests for th eyear 2019 are shown in the above table. We can see that there are 15 states with a 100% participation which is almost twice that of SAT participation. which could indicate that the ACT test is popular. While the SATs have way lower participation rates.

# %%
# States that have lowest participation rates SAT in 2019, below the rate of 0.30%
min_sat = participation[participation['sat_participation']<0.30].sort_values(by=['sat_participation'], ascending=True)
min_sat.head()
# Out:
#            state  sat_participation  act_participation
# 34  North Dakota               0.02               0.96
# 27      Nebraska               0.03               1.00
# 41  South Dakota               0.03               0.75
# 49     Wisconsin               0.03               1.00
# 24   Mississippi               0.03               1.00

# %% [markdown]
# #### Interpretation:
# The states that have the lowest SAT participation is North Dakota about 2%. But the ACT participation is way higher. Which indicates that the ACT is more preferred in this state.

# %%
# States that have lowest participation rates ACT in 2019, below the rate of 0.30%
min_act = participation[participation['act_participation']<0.30].sort_values(by=['act_participation'], ascending=True)
min_act.head()
# Out:
#             state  sat_participation  act_participation
# 19          Maine               0.99               0.06
# 39   Rhode Island               1.00               0.12
# 7        Delaware               1.00               0.13
# 29  New Hampshire               0.95               0.14
# 38   Pennsylvania               0.70               0.17

# %% [markdown]
# #### Interpretation:
# The state that has the lowest ACT participation is Maine, about 6%. But the SAT participation is way higher about 99%. Which indicates that the SAT is more preferred in this state.

# %%
#states with highest act composite scores for 2019 ACT.
maxact_comp = my_sat_act_19[['state','act_composite','act_participation', 'sat_participation']].sort_values(by=['act_composite'], ascending = False)
maxact_comp.head()
# Out:
#             state  act_composite  act_participation  sat_participation
# 21  Massachusetts           25.5               0.21               0.81
# 6     Connecticut           25.5               0.22               1.00
# 29  New Hampshire           25.0               0.14               0.95
# 39   Rhode Island           24.7               0.12               1.00
# 32       New York           24.5               0.22               0.79

# %% [markdown]
# #### Interpretation:
# The states that have the highest ACT composite scores are Massachusetts(avg of 25.5), Connecticut(avg of 25.5) and New Hampshire(avg of 25.0).
# However it should be noted that the particiapation rates for these states are relatively low.This is because the SAT is more popular in these states.With participation rates of more than 70%.

# %%
#states with lowest act composite scores for 2019 ACT.
minact_comp = my_sat_act_19[['state','act_composite']].sort_values(by=['act_composite'], ascending = True)
minact_comp.head()
# Out:
#              state  act_composite
# 28          Nevada           17.9
# 24     Mississippi           18.4
# 40  South Carolina           18.8
# 18       Louisiana           18.8
# 0          Alabama           18.9

# %%
#states with highest mean total scores for 2019 SAT
maxsat_total = my_sat_act_19[['state','sat_total']].sort_values(by=['sat_total'], ascending = False)
maxsat_total.head()
# Out:
#            state  sat_total
# 23     Minnesota       1284
# 49     Wisconsin       1283
# 41  South Dakota       1268
# 34  North Dakota       1263
# 27      Nebraska       1260

# %%
#states with lowest mean total scores for 2019 SAT
 
minsat_total = my_sat_act_19[['state','sat_total']].sort_values(by=['sat_total'], ascending = True)
minsat_total.head()
# Out:
#                    state  sat_total
# 48         West Virginia        943
# 36              Oklahoma        963
# 8   District of Columbia        975
# 7               Delaware        985
# 12                 Idaho        993

# %%
#National Average ACT score for 2019
national_avg = my_sat_act_19['act_composite'].mean()
print ('The National Average ACT score for 2019 is: ',national_avg )
# Out:
# The National Average ACT score for 2019 is:  21.464705882352934

# %% [markdown]
# #### Interpretation:
# The National average ACT score for 2019 is 21.46 out of 36. This means that we need ACT scores of 21 or higher to beat half the other high school students in the country.

# %%
# states that have >50% participation on both tests for 2019
act_sat_participation = my_sat_act_19[['state','sat_participation','act_participation']]

act_sat_participation[(act_sat_participation['sat_participation'] > 0.5) & \
                      (act_sat_participation.act_participation > 0.5)]
# Out:
#              state  sat_participation  act_participation
# 9          Florida               1.00               0.54
# 11          Hawaii               0.54               0.80
# 33  North Carolina               0.51               1.00
# 40  South Carolina               0.68               0.78

# %% [markdown]
# #### Interpretation:
# The states that have higher than 50% participation rates in ACT and SAT of 2019 are Florida, Hawaii, North Carolina and South Carolina.
# This indicates that the students of these states prefer both the SAT and ACT standardized tests.

# %%
# Which colleges have the highest median SAT and ACT scores for admittance?
my_sat_collegemajor.corr()
# Out:
#                      sat_testtakers  accept_rate  sat_reading_writing  \
# sat_testtakers             1.000000     0.997478             0.092261
# accept_rate                0.997478     1.000000             0.103632
# sat_reading_writing        0.092261     0.103632             1.000000
# sat_math                   0.185672     0.196504             0.892710
# new_sat_total              0.143995     0.155400             0.971475
#
#                      sat_math  new_sat_total
# sat_testtakers       0.185672       0.143995
# accept_rate          0.196504       0.155400
# sat_reading_writing  0.892710       0.971475
# sat_math             1.000000       0.974109
# new_sat_total        0.974109       1.000000

# %%
#Median score of total sat scores
my_sat_collegemajor['new_sat_total'].median()
# Out:
# 1066.5

# %% [markdown]
# #### Interpretation:
# The median is the middle value of the sorted SAT total column which is 1066.5. This is the 50th percentile of the enorolled students.

# %%
my_sat_collegemajor[['sat_testtakers', 'accept_rate', 'sat_reading_writing','sat_math',
                     'new_sat_total']].agg(['mean','median', 'min', 'max']).T
# Out:
#                              mean    median    min        max
# sat_testtakers       48394.500000  16370.50  283.0  331026.00
# accept_rate              0.025789      0.01    0.0       0.18
# sat_reading_writing    535.500000    537.00  458.0     597.00
# sat_math               523.000000    527.00  456.0     646.00
# new_sat_total         1058.500000   1066.50  916.0    1243.00

# %%
# top 5 most applied college major.
majors = my_sat_collegemajor[['college_major', 'sat_testtakers']].sort_values(by=['sat_testtakers'], ascending = False)
majors.head()
# Out:
#                                         college_major  sat_testtakers
# 14   Health Professions and related Clinical Sciences          331026
# 4   Business, Management, Marketing, and Related S...          221523
# 9                                         Engineering          194127
# 3                  Biological and Biomedical Sciences          155834
# 35                Visual and Performing Arts, General          130642

# %% [markdown]
# #### Interpretation:
# The top most intended college majors based on the number of 2019 highschool graduates who took SAT during highschool are "Health Professions and related Clinical Sciences" followed by "Business Management, Marketing and Related  Support Services" and "Engineering".

# %%
# Colleges that have the highest median SAT and ACT scores for admittance
my_sat_act_bycollege[['sat_25th_percentile', 'sat_75th_percentile', ]].agg(['mean','median', 'min', 'max']).T
# Out:
#                             mean  median     min     max
# sat_25th_percentile  1163.826355  1150.0   793.0  1490.0
# sat_75th_percentile  1358.892683  1350.0  1050.0  1580.0

# %%
# Mean Median Min and Max scores for ACT 

my_sat_act_bycollege[['act_25th_percentile', 'act_75th_percentile', ]].agg(['mean','median', 'min', 'max']).T
# Out:
#                           mean  median   min   max
# act_25th_percentile  24.712927    24.0  15.0  35.0
# act_75th_percentile  29.889756    30.0  19.0  36.0

# %%
#The college with highest SAT score of 75th percentile
my_sat_act_bycollege[my_sat_act_bycollege['sat_75th_percentile']==1580 ]
# Out:
#             school                                     policy_details  \
# 1  Harvard College  Harvard has adopted a one-year test optional p...
#
#    number_of_applicants  accept_rate  test_optional?_No  test_optional?_Yes  \
# 1                 42749        0.047                  0                   1
#
#    test_optional?_Yes (TB)  test_optional?_Yes (TF)  test_optional?_Yes*  \
# 1                        0                        0                    0
#
#    years_applicable_from_2021  sat_25th_percentile  sat_75th_percentile  \
# 1                           1               1460.0               1580.0
#
#    act_25th_percentile  act_75th_percentile
# 1                 33.0                 35.0

# %% [markdown]
# #### Interpretation:
# The college with the highest SAT score of 1530 is Harvard College. It has 42749 number applicants, and an acceptence rate of 4.7%.

# %%
#The college with the highest ACT score of 75th percentile
my_sat_act_bycollege[my_sat_act_bycollege['act_75th_percentile'] == 36.0]
# Out:
#                                   school  \
# 5     California Institute of Technology
# 6  Massachusetts Institute of Technology
#
#                                       policy_details  number_of_applicants  \
# 5  CalTech has adopted a two-year Test Blind poli...                  8367
# 6  MIT has adopted a one-year test optional polic...                 21706
#
#    accept_rate  test_optional?_No  test_optional?_Yes  \
# 5        0.064                  0                   0
# 6        0.067                  0                   1
#
#    test_optional?_Yes (TB)  test_optional?_Yes (TF)  test_optional?_Yes*  \
# 5                        1                        0                    0
# 6                        0                        0                    0
#
#    years_applicable_from_2021  sat_25th_percentile  sat_75th_percentile  \
# 5                           2                  NaN               1560.0
# 6                           1                  NaN               1570.0
#
# ...

# %% [markdown]
# #### Interpretation:
# The college with the highest median ACT score is California Institute of Technology and Massachusetts Institute of Technology with an absolute score of 36. Number of applicants for MIT was 21706 and acceptance rate of only 6.7%.

# %%
college_name=my_sat_act_bycollege.loc[my_sat_act_bycollege['act_75th_percentile']==36, 'school']
college_name
# Out:
# 5       California Institute of Technology
# 6    Massachusetts Institute of Technology
# Name: school, dtype: object

# %%
##colleges ranked by acceptance rates.

sorted_acceptrate = my_sat_act_bycollege[['school', 'number_of_applicants', 'accept_rate']].sort_values(by=['accept_rate'], ascending = True)
sorted_acceptrate[0:10]
# Out:
#                                   school  number_of_applicants  accept_rate
# 0                    Stanford University                 47452        0.043
# 1                        Harvard College                 42749        0.047
# 2                   Princeton University                 35370        0.055
# 3                    Columbia University                 40203        0.055
# 4                        Yale University                 36844        0.061
# 5     California Institute of Technology                  8367        0.064
# 6  Massachusetts Institute of Technology                 21706        0.067
# 7                       Brown University                 38674        0.071
# 8                  University of Chicago                 32283        0.073
# 9                         Pomona College                 10401        0.074

# %% [markdown]
# #### Interpretation:
# We can see here top 10 colleges with a very high number of applicants and have very low acceptance rates. These are the most selective colleges that admit only a fraction of their applicants. While over 47000 students applied to Stanford only 4.3% receieved an admission letter, same as Harvard College with an acceptance rate of 4.7%
# Colleges with one of the lowest acceptance rates often appear on lists of the best schools. Because of their prestige and reputation, these schools rank among the nation's most elite institutions of higher education.
# Resource: https://www.usnews.com/best-colleges/rankings/national-universities
#            https://oedb.org/rankings/acceptance-rate/

# %%
#school that has the most number of applicants
max_applicants = my_sat_act_bycollege['number_of_applicants'].max()
my_sat_act_bycollege[sat_act_bycollege['number_of_applicants']==max_applicants]
# Out:
#                                    school  \
# 24  University of California—​Los Angeles
#
#                                        policy_details  number_of_applicants  \
# 24  The UC system has adopted a two-year test opti...                111322
#
#     accept_rate  test_optional?_No  test_optional?_Yes  \
# 24        0.123                  0                   1
#
#     test_optional?_Yes (TB)  test_optional?_Yes (TF)  test_optional?_Yes*  \
# 24                        0                        0                    0
#
#     years_applicable_from_2021  sat_25th_percentile  sat_75th_percentile  \
# 24                           4               1290.0               1510.0
#
#     act_25th_percentile  act_75th_percentile
# 24                 27.0                 34.0

# %% [markdown]
# #### Interpretation:
# The highest number of applicants to a university is 111322, to University of California—Los Angeles with an aceeptance rate of 12%.

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Data Visualization

# %%
# Correlation matrix for the SAT ACT 2019 dataset
sat_act_corr = my_sat_act_19.corr()

sat_act_corr
# Out:
#                          sat_participation  sat_reading_and_writing  sat_math  \
# sat_participation                 1.000000                -0.873453 -0.845841
# sat_reading_and_writing          -0.873453                 1.000000  0.986026
# sat_math                         -0.845841                 0.986026  1.000000
# sat_total                        -0.861786                 0.996134  0.996825
# act_participation                -0.865435                 0.688592  0.643101
# act_composite                     0.724619                -0.460065 -0.390668
#
#                          sat_total  act_participation  act_composite
# sat_participation        -0.861786          -0.865435       0.724619
# sat_reading_and_writing   0.996134           0.688592      -0.460065
# sat_math                  0.996825           0.643101      -0.390668
# sat_total                 1.000000           0.666966      -0.424782
# act_participation         0.666966           1.000000      -0.866819
# ...

# %%
#Heatmap for the SAT ACT 2019 dataset
plt.figure(figsize=  (10,10))
ax = plt.axes()
ax.set_title('Correlation Matrix for SAT and ACT 2019')
# plt.xticks(rotation =20)
sns.heatmap(sat_act_corr,annot = True, cmap='coolwarm');

# %% [markdown]
# #### Interpretation:
# We can see the correlation between all the numeric variables in our dataset. Stronger correlation pops out in darker shades and weaker correlation in lighter.

# %%
# Correlation between the SAT ACT 2019 scores and ACT total score
# credits: https://www.geeksforgeeks.org/colormaps-in-seaborn-heatmaps/
act_corr = my_sat_act_19.corr()[['act_composite']].sort_values(('act_composite'), ascending = False)
plt.figure(figsize=  (5,10))
ax = plt.axes()
ax.set_title('Correlation for SAT and ACT 2019 scores by States and ACT Composite scores')
colormap= sns.color_palette('Greens')
sns.heatmap(act_corr,annot = True,cmap = colormap, annot_kws={'fontsize': 12, 'fontweight': 'bold'} );

# %% [markdown]
# #### Interpretation:
# The heatmap above shows ACT composite score is most positively correlated to the SAT Participation about 0.72. Which indicates the as ACT participation increases, the composite test score decreases.

# %%
# Correlation between the SAT ACT 2019 scores by state and SAT total score

sat_corr = my_sat_act_19.corr()[['sat_total']].sort_values(('sat_total'), ascending = False)
plt.figure(figsize=  (5,10))
ax = plt.axes()
ax.set_title('Correlation for SAT and ACT 2019 scores by States and SAT total scores')
colormap= sns.color_palette('Blues')
sns.heatmap(sat_corr,annot = True,cmap = colormap, annot_kws={'fontsize': 12, 'fontweight': 'bold'} );

# %% [markdown]
# #### Interpretation:
# The heatmap above shows SAT total score is most positively correlated to the ACT Participation about 0.67. Which indicates the as SAT participation increases, the total test score decreases same as above with ACT socres.

# %%
# Histogram for the Participation rates for SAT and ACT across the US states
fig, ax = plt.subplots(2, 1, figsize=(16, 9), sharex=True)

ax[0].set_title('SAT Participation Across U.S. States')
ax[0].hist(my_sat_act_19['sat_participation'], color = 'teal')
ax[0].set_ylabel('Number of States')
ax[0].axvline(x = np.mean(my_sat_act_19['sat_participation']), color='orange')

ax[1].set_title('ACT Participation Across U.S. States')
ax[1].set_xlabel('Participation rates')
ax[1].set_ylabel('Number of States')
ax[1].hist(my_sat_act_19['act_participation'], color = 'olive')
ax[1].axvline(x = np.mean(my_sat_act_19['act_participation']), color='orange')


plt.tight_layout()

# %% [markdown]
# #### Interpretation:
# We can compare the participation rates from the above histograms for SAT and ACT across the US states.  The distributions of the 2 plots seem opposite to eachother.. Meaning that when there is higher SAT participation ACT participation is low. ACT participation prevails across the US states with more 100% participations than SAT

# %%
participation = my_sat_act_19[['state','sat_participation','act_participation']]
participation['total'] = participation['sat_participation']+participation['act_participation']

# %%
# Stacked Bar Plot of Total ACT and SAT participation: the 2 participations are stacked over eachother. 

import matplotlib.patches as mpatches
sorted_act['total'] = sorted_act['sat_participation']+sorted_act['act_participation'] 

sns.set(style="darkgrid")
plt.figure(figsize=(14, 14))
bar1 = sns.barplot(x='state',  y="total", data=sorted_act, color='lightblue')
bar2 = sns.barplot(x="state", y="sat_participation", data=sorted_act, ci=None,  color='orange')
top_bar = mpatches.Patch(color='lightblue', label='act_participation')
bottom_bar = mpatches.Patch(color='orange', label='sat_participation')
plt.legend(handles=[top_bar, bottom_bar])
bar1.set(ylabel='Participation')
bar1.set_xticklabels(bar1.get_xticklabels(), rotation = 90)
# show the graph
plt.show()

# %% [markdown]
# #### Interpretation:
# The above stacked bar graph shows the sorted total participation rates for the states.
# we see that states that have higher SAT participation have lower ACT participation and vice versa. for example: Florida have 100% participation in SAT and 54% in ACT. State of Iowa has 3% SAT participation and 66% in ACT.
# which indicates if a state has higher participation in one standardized test then the other test has lower participation.

# %%
sns.boxplot(my_sat_act_19['sat_total'], color='skyblue')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sat_total'>

# %%
sns.boxplot(my_sat_act_19['act_composite'], color = 'goldenrod')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='act_composite'>

# %% [markdown]
# #### Interpretation:
# The spread of the scores for both the SAT and ACT are very similar. Even though the score ranges vary. SAT score ranges from out of 400-1600 and act ranges out of 1-36.
# The box plot also indicates that the distribution is positively skewed. Meaning the median(vertical line in the box) is closer to the Q1 for both the plots. The ends of the whiskers represents the minimum and the maximum value. There are no outliers in this dataset.

# %%
# Scatterplot of SAT total score vs the SAT participation
#credits: https://datavizpyr.com/how-to-make-scatter-plot-with-regression-line-using-seaborn-in-python/
sns.set(style='whitegrid')
 
sns.regplot(x="sat_total",
                    y="sat_participation",
                    data=my_sat_act_19).set(title='SAT total score vs the SAT participation');

# %%
# Scatterplpot of SAT total score vs the SAT participation
sns.set(style='whitegrid')
 
sns.regplot(x="act_composite",
                    y="act_participation",
                    data=my_sat_act_19).set(title='ACT Composite score vs ACT participation');

# %% [markdown]
# #### Interpretation:
# The scatterplots for the SAT and ACT scores and their Participation shows us the trend line, which are very similar for both the tests. We can conclude that higher test participation can lower the mean test scores for the state. (The 2 variables have a negetive correlation, this is also shown in the heatmap in the earlier visualization.

# %%
# Data visualization for the SAT 2019 by college majors
sorted_majors = my_sat_collegemajor[['college_major', 'sat_testtakers']].sort_values(by=['sat_testtakers'], ascending = True)
plt.figure(figsize = (15, 15))

plt.barh(sorted_majors['college_major'], sorted_majors['sat_testtakers'])

plt.title('Intended College Major Vs SAT testtakers')
plt.yticks(rotation = 20)
plt.xlabel('sat_testtakers');

# %% [markdown]
# #### Interpretation:
# The top most intended college majors based on the number of 2019 highschool graduates who took SAT during highschool are "Health Professions and related Clinical Sciences" followed by "Business Management, Marketing and Related  Support Services" and "Engineering" are among the top 5 Majors.
# We can also see that a large amount of testtakers are undecided on the major.

# %%
# SAT scores and Intended majors sorted by Sscores higher than 1100

sorted_sat_majors = my_sat_collegemajor[['college_major', 'new_sat_total']].sort_values(by=['new_sat_total'], ascending = False)
result = sorted_sat_majors[sorted_sat_majors['new_sat_total']> 1100]
result
# Out:
#                                         college_major  new_sat_total
# 19                         Mathematics and Statistics           1243
# 27                                  Physical Sciences           1203
# 32                                    Social Sciences           1164
# 6   Computer and Information Sciences and Support ...           1156
# 22                    Multi/Interdisciplinary Studies           1155
# 17  Liberal Arts and Sciences, General Studies and...           1140
# 9                                         Engineering           1140
# 3                  Biological and Biomedical Sciences           1138
# 26                   Philosophy and Religious Studies           1120
# 11            English Language and Literature/Letters           1118
# 23                 Natural resources and Conservation           1105
# 18                      Library Science/Librarianship           1104
# 16                             Legal Studies, General           1104
# ...

# %% [markdown]
# #### Interpretation:
# Students who plan on majoring in Science and Math related majors, Engineering and techology related majors tend do better on SAT. We can see here that the highest SAT scorer's intended majors are Mathematics and Statistics followed by Physical Sciences and Social Sciences.

# %%
# Plot of the above data

plt.figure(figsize = (10,5))

plt.barh(result['college_major'], result['new_sat_total'])

plt.title('Intended College Major Vs SAT total scores')
plt.yticks(rotation = 20)
plt.xlabel('SAT total scores');

# %% [markdown]
# #### Interpretation:
# We can conclude from the above plot, Students who desire to major in Science and Math statistics related majors, Engineering and techology related majors or Multi/Interdisciplinary Studies should have a score higher than 1100.

# %%
# Plot of SAT testtakers vs the Accept rate

sns.set(style='whitegrid')
 
sns.regplot(x="sat_testtakers",
                    y="accept_rate",
                    data=my_sat_collegemajor).set(title='SAT testtakers vs the Accept rate');

# %% [markdown]
# #### Interpretation:
# We can see here that the higher the testtakers higher are the acceptance rates. The 2 have avery high positive correlation.

# %%
accept_majors = my_sat_collegemajor[['college_major', 'accept_rate']].sort_values(by=['accept_rate'], ascending = True)
plt.figure(figsize = (15, 15))

plt.barh(accept_majors['college_major'], accept_majors['accept_rate'])

plt.title('Intended College Major Vs Accept rate')
plt.yticks(rotation = 20)
plt.xlabel('accept_rate');

# %% [markdown]
# #### Interpretation:
# We can see that the accept rate for Health Professions and related Clinical Sciences and Business, Management, Marketing and Engineering have the highest accept rates, the rates coincide proportionally with the SAT testtakers. Higher the testtakers higher is the acceptence rate.

# %%
#  Top 10 Intended majors and their acceptance rates.
accept_majors = my_sat_collegemajor[['college_major', 'accept_rate']].sort_values(by=['accept_rate'], ascending = False)
accept_majors[0:10]
# Out:
#                                         college_major  accept_rate
# 14   Health Professions and related Clinical Sciences         0.18
# 4   Business, Management, Marketing, and Related S...         0.12
# 9                                         Engineering         0.11
# 3                  Biological and Biomedical Sciences         0.08
# 35                Visual and Performing Arts, General         0.07
# 37                                          Undecided         0.07
# 6   Computer and Information Sciences and Support ...         0.04
# 8                                           Education         0.04
# 31                   Security and Protective Services         0.04
# 29                                Psychology, General         0.04

# %%
my_sat_collegemajor.head()
# Out:
#                                        college_major  sat_testtakers  \
# 0  Agriculture, AgricultureOperations, and Relate...           24913
# 1                  Architecture and Related Services           28988
# 2         Area, Ethnic, Cultural, and Gender Studies            2629
# 3                 Biological and Biomedical Sciences          155834
# 4  Business, Management, Marketing, and Related S...          221523
#
#    accept_rate  sat_reading_writing  sat_math  new_sat_total
# 0         0.01                  496       481            977
# 1         0.02                  520       527           1047
# 2         0.00                  536       504           1040
# 3         0.08                  572       566           1138
# 4         0.12                  534       537           1071

# %%
sorted_sat_math = my_sat_collegemajor[['college_major', 'sat_math']].sort_values(by=['sat_math'], ascending = False)

result1=sorted_sat_math[0:5]

# %%
plt.figure(figsize = (10,5))

plt.barh(result1['college_major'], result1['sat_math'])

plt.title('Intended College Major Vs SAT Math scores')
plt.yticks(rotation = 20)
plt.xlabel('Average SAT Math');

# %% [markdown]
# #### Interpretation:
# Students with highest average SAT math scores see themselves as future Mathematicians and statistics Majors

# %%
# SAT and ACT By college Dataset
# Plot of Number of Applicats Vs Accept rate

sns.set(style='whitegrid')
 
sns.regplot(x="number_of_applicants",
                    y="accept_rate",
                    data=my_sat_act_bycollege).set(title='Number of Applicats Vs Accept rate');

# %%
#colleges ranked by acceptance rates.
top10colleges= sorted_acceptrate[0:10]

plt.figure(figsize = (15, 5))
plt.bar(top10colleges['school'], top10colleges['accept_rate'])
plt.title('colleges ranked by acceptance rates')
plt.xlabel('Colleges/school names')
plt.ylabel('Acceptance rate')
plt.xticks(rotation = 25);

# %% [markdown]
# #### Interpretation:
# The top 10 colleges with a very high number of applicants have very low acceptance rates. These are the most selective colleges that admit only a fraction of their applicants. While over 47000 students applied to Stanford only 4.3% received an admission letter, same as Harvard College with an acceptance rate of 4.7%
# Colleges with one of the lowest acceptance rates often appear on lists of the best schools. Because of their prestige and reputation, these schools rank among the nation's most elite institutions of higher education.
# Resource: ([source](https://www.usnews.com/best-colleges/rankings/national-universities))
#            ([source](https://oedb.org/rankings/acceptance-rate/))

# %%
# Plot of Acceptance rates for SAT 75th percentiles.

sns.set(style='whitegrid')
 
sns.regplot(x="sat_75th_percentile",
                    y="accept_rate",
                    data=my_sat_act_bycollege).set(title='SAT 75th Percentile Vs Accept rate');

# %%
# Plot of Acceptance rates for ACT 75th percentiles.

sns.set(style='whitegrid')
 
sns.regplot(x="act_75th_percentile",
                    y="accept_rate",
                    data=my_sat_act_bycollege).set(title='ACT 75th Percentile Vs Accept rate');

# %% [markdown]
# #### Interpretation:
# Reinstating our point here: Higher the scores lower the acceptance rates.
# This is the case for both ACT and SAT 75th percentile scores for the enrolled students and acceptance rates for the new admits are inversely proportional. We can further state that the colleges with high scores and low acceptance rates are among the prestigious colleges.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Test Averages and Participation Correlate Negatively- for the States that have larger participation, the scores represent the average of the entire student body, thus pulling the state average down. And states that have lower participation rates have average score reflective of only the most high-performing students of the state. SAT total score is most positively correlated to the ACT Participation about 0.67.  SAT total score is negatively correlated to the SAT Participation indicating as SAT participation increases, the total SAT score decreases. When we compared the participation rates for SAT and ACT across the US states, The distributions of the 2 plots seem opposite to eachother.. Meaning that when there is higher SAT participation the ACT participation is low. More states have a 100% ACT participations compared to SAT.
#
# SAT & ACT Scores Correlate Negatively- States that have higher average SAT scores have lower average ACT scores and its the same the other way around.
#
# The spread of the scores for both the SAT and ACT are very similar. Even though the score ranges vary. SAT score ranges from out of 400-1600 and act ranges out of 1-36. We see this in the boxplot above.

# %% [markdown]
# Intended college major indicates that the higher SAT scorers choose majors in STEM related fields.
# Students who desire to major in Science and Math statistics, Engineering and techology or Multi/Interdisciplinary Studies should score higher than 1100 in SATs
# The acceptance rate for Health Professions and related Clinical Sciences and Business, Management, Marketing and Engineering are the highest. The rates coincide proportionally with the SAT testtakers. Higher the testtakers higher is the acceptence rate.
# Students with highest average SAT math scores see themselves as future Mathematicians and statistics Majors

# %% [markdown]
# The ACT and SAT 75th percentile scores for the enrolled students and acceptance rates for the new admits are inversely proportional. Acceptance rates decrease as scores increases. We can further state that the colleges with high scores and low acceptance rates are among the prestigious colleges. Meaning the more competitive a school is the higher and narrower is the margin of test scores.
#
# The pandemic forced a larger number of universities to go test-optional, leaving them no-choice but to experiment this option. And due to this many schools will recieve larger number of applicants and from a broader pool and more diverse applicants. In addition to a strong academic record, these colleges will also look for well-rounded applicants who bring something unique to the student body. Highlighting extracurricular activities.
#
# It is upto the colleges to evaluate how the test-optional admissions will benefit them before reconsidering the value of the tests. This means looking at all the data before and after.
